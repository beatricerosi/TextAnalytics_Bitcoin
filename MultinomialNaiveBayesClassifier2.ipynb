# %%
import numpy as np 
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('...\groupBy.csv', delimiter=',', lineterminator='\n', low_memory=False)
dataset
# Out:
#     Unnamed: 0        date                                              tweet  \
# 0            0  2019-05-06  dear community 🔷 glad announce det listed cryp...
# 1            1  2019-05-07  bitcoin surged year,scope project may seem ove...
# 2            2  2019-05-08  btc meant satoshi nakamoto created fixed face ...
# 3            3  2019-05-09  may utc € £ bitcoin btc pic twitter com qkuprt...
# 4            4  2019-05-10  btc usd btcusd btc usd btc fibs long short wcx...
# 5            5  2019-05-11  btc smashed support level broke months ago too...
# 6            6  2019-05-12  weenzee invest arbitrage bitcoin risk antihack...
# 7            7  2019-06-03  days profit bitcoin took market storm bitcoin ...
# 8            8  2019-06-04  buy signal dash btc binance generated get tech...
# 9            9  2019-06-05  switch bitcoin miners good worldenvironmentday...
# 10          10  2019-06-06  🌈 addresscategory donation wallets addresses 🔗...
# ...

# %%
# for splitting dataset into train set and test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(dataset["tweet"],dataset["value\r"], test_size = 0.33, random_state = 10)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (46,)
# (24,)
# (46,)
# (24,)

# %%
# for vectorizing words
from sklearn.feature_extraction.text import CountVectorizer

# %%
vect = CountVectorizer(stop_words='english')
vect.fit(X_train)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
print(vect.get_feature_names()[0:20])
print(vect.get_feature_names()[-20:])
# Out:
# ['aa', 'aaa', 'aaaaa', 'aaaaaaaaa', 'aaaaaaaaaa', 'aaaaaaaaah', 'aaaaaaaand', 'aaaaaaahhhh', 'aaaaaaand', 'aaaaaaany', 'aaaaaannnny', 'aaaaah', 'aaaaalways', 'aaaaand', 'aaaaarggggh', 'aaaaebdcddbdbafdfeccb', 'aaaah', 'aaaamhim', 'aaaand', 'aaaannd']
# ['𝙈𝙤𝙣𝙖𝙧𝙘𝙝', '𝙏𝙞𝙢𝙚', '𝙏𝙧𝙖𝙙𝙞𝙣𝙜', '𝙒𝙝𝙖𝙩', '𝙖𝙡𝙡𝙤𝙘𝙖𝙩𝙞𝙤𝙣', '𝙖𝙨', '𝙖𝙩', '𝙘𝙡𝙞𝙘𝙠', '𝙞𝙣𝙨𝙩𝙧𝙪𝙢𝙚𝙣𝙩𝙨', '𝙞𝙨', '𝙢𝙤𝙨𝙩', '𝙧𝙞𝙨𝙠𝙨', '𝙩𝙚𝙧𝙧𝙞𝙛𝙞𝙚𝙙', '𝙩𝙝𝙚', '𝙩𝙝𝙚𝙞𝙧', '𝙫𝙭', '𝚃𝚊𝚛𝚐𝚎𝚝', '𝚫d', '𝚫h', '𝚫w']

# %%
X_train_df = vect.transform(X_train)
X_test_df = vect.transform(X_test)
type(X_test_df)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
prediction = dict()
# Naive Bayes Machine Learning Model
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
model = BernoulliNB()
model.fit(X_train_df,y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
#faccio la predizione su X_test usando il naive bayes
prediction["naive_bayes"] = model.predict(X_test_df)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
# accuracy
accuracy_score(y_test,prediction["naive_bayes"])
# Out:
# 0.6666666666666666

# %%
#classification report
print(classification_report(y_test, prediction['naive_bayes'], target_names = ["bear", "bull"]))
# Out:
#               precision    recall  f1-score   support
#
#         bear       0.58      1.00      0.73        11
#         bull       1.00      0.38      0.56        13
#
#     accuracy                           0.67        24
#    macro avg       0.79      0.69      0.64        24
# weighted avg       0.81      0.67      0.64        24
