# %% [markdown]
# # Loading data

# %%
import pandas as pd
df = pd.read_csv('.../TrainTestTOT.csv', delimiter=',', skiprows=0, lineterminator='\n', low_memory=False)
df
# Out:
#         Unnamed: 0        date             user               timestamp  \
# 0                0  2019-05-10       IdeasPrime  2019-05-10 21:42:01+00
# 1                4  2019-05-10       harbington  2019-05-10 13:20:10+00
# 2                5  2019-05-12         ojo_azul  2019-05-12 15:37:12+00
# 3                7  2019-05-12    crypto_pump_1  2019-05-12 19:50:41+00
# 4                9  2019-05-10  DavidWa20090980  2019-05-10 18:09:06+00
# ...            ...         ...              ...                     ...
# 599995       59995  2019-11-03  fairfieldcurren  2019-11-03 05:21:52+00
# 599996       59996  2019-11-03  leboncoincrypto  2019-11-03 11:04:17+00
# 599997       59997  2019-11-03          ao_coin  2019-11-03 05:00:27+00
# 599998       59998  2019-11-03    theautomatski  2019-11-03 15:35:16+00
# 599999       59999  2019-11-03      chetanmaya1  2019-11-03 15:18:05+00
#
#                                                     clean     pos    neg  \
# 0          btc usd btcusd btc usd btc fibs long short wcx  0.0000  0.000
# 1       eth also possible ethereum pump time bitcoin d...  0.5859  0.081
# 2       weenzee invest arbitrage bitcoin risk antihack... -0.2732  0.110
# 3       binance update fun aion rlc sc join telegram c...  0.6705  0.000
# 4                               could bitcoin pin looking  0.0000  0.000
# ...                                                   ...     ...    ...
# 599995  btc capital management inc million holdings ma...  0.0000  0.000
# 599996  blockchain crypto bitcoin ethereum trading fir... -0.7184  0.316
# 599997      algorithm mtlusdt desable trade btc volatiliy  0.0000  0.000
# 599998  investments wavesplatform cybersecurity detroi...  0.5423  0.000
# 599999           highest profitable asset earth bitcoin 🤑  0.6597  0.000
#
#           neu  compound     value  week\r
# 0       1.000     0.000  bull\r\r      19
# 1       0.704     0.215  bull\r\r      19
# 2       0.890     0.000  bull\r\r      19
# 3       0.744     0.256  bull\r\r      19
# 4       1.000     0.000  bull\r\r      19
# ...       ...       ...       ...     ...
# 599995  1.000     0.000  bear\r\r      44
# 599996  0.684     0.000  bear\r\r      44
# 599997  1.000     0.000  bear\r\r      44
# 599998  0.877     0.123  bear\r\r      44
# 599999  0.357     0.643  bear\r\r      44
#
# [600000 rows x 11 columns]

# %% [markdown]
# # Inizio di doc2vec

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
#tokenize e tag il testo dei tweets
tweet_document = [TaggedDocument(doc.split(' '), [i]) 
             for i, doc in enumerate(df.clean)]
#visualizza i tweet taggati
tweet_document[:2]
# Out:
# C:\Users\fazzo\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# [TaggedDocument(words=['btc', 'usd', 'btcusd', 'btc', 'usd', 'btc', 'fibs', 'long', 'short', 'wcx'], tags=[0]),
#  TaggedDocument(words=['eth', 'also', 'possible', 'ethereum', 'pump', 'time', 'bitcoin', 'drops', 'saying', 'going', 'happen', 'looking', 'eth', 'btc', 'chart', 'definitely', 'cards', 'kind', 'tension', 'field', 'right', 'btc', 'crypto'], tags=[1])]

# %% [markdown]
# # Modello

# %%
#instanzia il modello
model = Doc2Vec(vector_size=64, window=2, min_count=1, workers=8, epochs = 10)
#crea il vocabolario
model.build_vocab(tweet_document)
#addestra il modello
model.train(tweet_document, total_examples=model.corpus_count, epochs=model.epochs)

# %%
model.wv.key_to_index
# Out:
# {'bitcoin': 0,
#  'btc': 1,
#  'crypto': 2,
#  'cryptocurrency': 3,
#  'blockchain': 4,
#  '’': 5,
#  'eth': 6,
#  'price': 7,
#  'ethereum': 8,
#  'xrp': 9,
#  'buy': 10,
#  'market': 11,
#  'money': 12,
#  'trading': 13,
#  'k': 14,
#  'time': 15,
#  'like': 16,
#  'get': 17,
#  'news': 18,
#  'new': 19,
#  'amp': 20,
#  'one': 21,
#  'via': 22,
#  'ltc': 23,
#  '️': 24,
#  'people': 25,
#  'usd': 26,
#  'binance': 27,
#  'litecoin': 28,
#  'gt': 29,
#  'top': 30,
#  'would': 31,
#  'see': 32,
#  'free': 33,
#  'gold': 34,
#  'good': 35,
#  'jobs': 36,
#  'us': 37,
#  'hiring': 38,
#  'careers': 39,
#  'cryptocurrencies': 40,
#  'think': 41,
#  'last': 42,
#  'exchange': 43,
#  'go': 44,
#  'long': 45,
#  'still': 46,
#  'going': 47,
#  'use': 48,
#  'coin': 49,
#  'bch': 50,
#  'ripple': 51,
#  'trade': 52,
#  'value': 53,
#  'make': 54,
#  'know': 55,
#  'info': 56,
#  'mining': 57,
#  'back': 58,
#  'ico': 59,
#  'trx': 60,
#  'today': 61,
#  '🚀': 62,
#  'could': 63,
#  'world': 64,
#  'twitter': 65,
#  'next': 66,
#  'first': 67,
#  'h': 68,
#  'day': 69,
#  'altcoins': 70,
#  'altcoin': 71,
#  '“': 72,
#  'investment': 73,
#  'sell': 74,
#  'cash': 75,
#  'need': 76,
#  'right': 77,
#  'best': 78,
#  '📋': 79,
#  'alts': 80,
#  '”': 81,
#  'united': 82,
#  'read': 83,
#  'way': 84,
#  'invest': 85,
#  'even': 86,
#  'want': 87,
#  'link': 88,
#  'project': 89,
#  'short': 90,
#  'forex': 91,
#  'eos': 92,
#  'volume': 93,
#  'currency': 94,
#  'much': 95,
#  'ai': 96,
#  'cryptonews': 97,
#  'great': 98,
#  'also': 99,
#  'daily': 100,
#  'btcusd': 101,
#  'x': 102,
#  'wallet': 103,
#  'take': 104,
#  '🔥': 105,
#  'support': 106,
#  'cryptotrading': 107,
#  'st': 108,
#  'years': 109,
#  'bnb': 110,
#  'fintech': 111,
#  'real': 112,
#  'join': 113,
#  'big': 114,
#  'libra': 115,
#  'days': 116,
#  'china': 117,
#  'may': 118,
#  'future': 119,
#  'profit': 120,
#  'high': 121,
#  'digital': 122,
#  'look': 123,
#  '…': 124,
#  'many': 125,
#  'bitcoins': 126,
#  '😂': 127,
#  'coins': 128,
#  'investing': 129,
#  'business': 130,
#  'well': 131,
#  '‘': 132,
#  'week': 133,
#  'bullish': 134,
#  '📈': 135,
#  'since': 136,
#  'really': 137,
#  'never': 138,
#  'xlm': 139,
#  'platform': 140,
#  'let': 141,
#  'network': 142,
#  '–': 143,
#  'start': 144,
#  'u': 145,
#  'bsv': 146,
#  'satoshi': 147,
#  'year': 148,
#  'ada': 149,
#  'using': 150,
#  'every': 151,
#  'token': 152,
#  'better': 153,
#  'say': 154,
#  'got': 155,
#  'bitcoincash': 156,
#  'tech': 157,
#  'airdrop': 158,
#  'analysis': 159,
#  'million': 160,
#  'signal': 161,
#  'markets': 162,
#  'fiat': 163,
#  'earn': 164,
#  'everyone': 165,
#  'coinbase': 166,
#  'facebook': 167,
#  '➡': 168,
#  'check': 169,
#  'alert': 170,
#  'technology': 171,
#  'buying': 172,
#  'hodl': 173,
#  'another': 174,
#  'says': 175,
#  'noticias': 176,
#  'chart': 177,
#  'rt': 178,
#  'around': 179,
#  'run': 180,
#  'full': 181,
#  'pay': 182,
#  'etc': 183,
#  'bull': 184,
#  'soon': 185,
#  'bank': 186,
#  'move': 187,
#  'dash': 188,
#  'keep': 189,
#  'work': 190,
#  'thanks': 191,
#  'r': 192,
#  'hit': 193,
#  'current': 194,
#  'looking': 195,
#  'bitcoinnews': 196,
#  'love': 197,
#  'usdt': 198,
#  'worth': 199,
#  'uk': 200,
#  'follow': 201,
#  '✅': 202,
#  'finance': 203,
#  'made': 204,
#  'trump': 205,
#  'come': 206,
#  'kingdom': 207,
#  'level': 208,
#  'dollar': 209,
#  'change': 210,
#  'neo': 211,
#  'please': 212,
#  'ever': 213,
#  'coming': 214,
#  'help': 215,
#  'system': 216,
#  'already': 217,
#  'global': 218,
#  'something': 219,
#  '📉': 220,
#  'usa': 221,
#  'states': 222,
#  'stop': 223,
#  'financial': 224,
#  'block': 225,
#  'account': 226,
#  'live': 227,
#  'sure': 228,
#  'sales': 229,
#  'data': 230,
#  'end': 231,
#  'post': 232,
#  'pump': 233,
#  'thing': 234,
#  'give': 235,
#  'london': 236,
#  'send': 237,
#  'term': 238,
#  'said': 239,
#  'used': 240,
#  'investors': 241,
#  'times': 242,
#  'life': 243,
#  '💰': 244,
#  'always': 245,
#  'lol': 246,
#  'banks': 247,
#  'update': 248,
#  'hold': 249,
#  'point': 250,
#  'payments': 251,
#  'looks': 252,
#  'believe': 253,
#  'team': 254,
#  'hours': 255,
#  'low': 256,
#  'lot': 257,
#  'power': 258,
#  'tron': 259,
#  'target': 260,
#  'yet': 261,
#  '→': 262,
#  'bitcoinmining': 263,
#  'stocks': 264,
#  'developer': 265,
#  'decentralized': 266,
#  'hour': 267,
#  'month': 268,
#  'hard': 269,
#  'getting': 270,
#  'fund': 271,
#  'without': 272,
#  'payment': 273,
#  'bought': 274,
#  'based': 275,
#  'learn': 276,
#  'app': 277,
#  'th': 278,
#  'vs': 279,
#  'company': 280,
#  'resistance': 281,
#  'break': 282,
#  'asset': 283,
#  'two': 284,
#  'bitcoin\r': 285,
#  'goes': 286,
#  'anyone': 287,
#  'understand': 288,
#  'making': 289,
#  'community': 290,
#  'latest': 291,
#  'close': 292,
#  'months': 293,
#  'b': 294,
#  'find': 295,
#  'might': 296,
#  'nothing': 297,
#  'startup': 298,
#  'alt': 299,
#  'exchanges': 300,
#  'sign': 301,
#  'yes': 302,
#  'dominance': 303,
#  'win': 304,
#  'watch': 305,
#  'store': 306,
#  'open': 307,
#  'telegram': 308,
#  'actually': 309,
#  'transactions': 310,
#  'tweet': 311,
#  'tether': 312,
#  'try': 313,
#  'xmr': 314,
#  'users': 315,
#  'ago': 316,
#  'things': 317,
#  'security': 318,
#  'xbt': 319,
#  'risk': 320,
#  '—': 321,
#  'tokensale': 322,
#  'futures': 323,
#  'ieo': 324,
#  'man': 325,
#  'higher': 326,
#  'makes': 327,
#  'stock': 328,
#  'traders': 329,
#  'past': 330,
#  'drop': 331,
#  'maybe': 332,
#  'guys': 333,
#  'adoption': 334,
#  'cap': 335,
#  'someone': 336,
#  'wait': 337,
#  'part': 338,
#  'shit': 339,
#  'group': 340,
#  'ratio': 341,
#  'less': 342,
#  'everything': 343,
#  'funding': 344,
#  'game': 345,
#  'weekly': 346,
#  'case': 347,
#  'smart': 348,
#  '\u200d': 349,
#  'easy': 350,
#  'possible': 351,
#  'government': 352,
#  'though': 353,
#  'video': 354,
#  'rally': 355,
#  'scam': 356,
#  'dump': 357,
#  'little': 358,
#  'major': 359,
#  'true': 360,
#  'assets': 361,
#  'tokens': 362,
#  'become': 363,
#  'address': 364,
#  'bearish': 365,
#  'funds': 366,
#  'arbitrage': 367,
#  'technicalanalysis': 368,
#  'c': 369,
#  'anything': 370,
#  'done': 371,
#  'away': 372,
#  'billion': 373,
#  'seems': 374,
#  'moving': 375,
#  'india': 376,
#  'bad': 377,
#  'bitmex': 378,
#  'ether': 379,
#  'cashflow': 380,
#  'trying': 381,
#  'hope': 382,
#  'put': 383,
#  'fees': 384,
#  'selling': 385,
#  'iot': 386,
#  'prices': 387,
#  'transaction': 388,
#  'far': 389,
#  'key': 390,
#  'interesting': 391,
#  'moon': 392,
#  'idea': 393,
#  'bigdata': 394,
#  'trader': 395,
#  'bonus': 396,
#  'stellar': 397,
#  'btc\r': 398,
#  'strong': 399,
#  'generated': 400,
#  'signals': 401,
#  'ca': 402,
#  'dm': 403,
#  'investor': 404,
#  'launch': 405,
#  'monero': 406,
#  'supply': 407,
#  'nice': 408,
#  'enough': 409,
#  'must': 410,
#  'ready': 411,
#  '🤣': 412,
#  'currently': 413,
#  'set': 414,
#  'play': 415,
#  'bittrex': 416,
#  'lightning': 417,
#  'started': 418,
#  'return': 419,
#  'sale': 420,
#  'channel': 421,
#  'huge': 422,
#  'service': 423,
#  'miners': 424,
#  'ceo': 425,
#  'trust': 426,
#  'trend': 427,
#  'space': 428,
#  'profits': 429,
#  'holding': 430,
#  'automatedtrading': 431,
#  'visit': 432,
#  'per': 433,
#  'investments': 434,
#  'bot': 435,
#  'chain': 436,
#  'tell': 437,
#  'sats': 438,
#  'dollars': 439,
#  'number': 440,
#  'different': 441,
#  '👍': 442,
#  'early': 443,
#  'happy': 444,
#  'software': 445,
#  'show': 446,
#  'wrong': 447,
#  'old': 448,
#  'call': 449,
#  'saying': 450,
#  'cryptocurrencynews': 451,
#  'giveaway': 452,
#  'success': 453,
#  'bulls': 454,
#  'probably': 455,
#  'mean': 456,
#  'needs': 457,
#  'waves': 458,
#  'gains': 459,
#  'report': 460,
#  'node': 461,
#  'mine': 462,
#  'waiting': 463,
#  'dont': 464,
#  'internet': 465,
#  'itos': 466,
#  'code': 467,
#  'online': 468,
#  'thank': 469,
#  'lost': 470,
#  'bitfinex': 471,
#  'privateequity': 472,
#  'w': 473,
#  'safe': 474,
#  'increase': 475,
#  'momentum': 476,
#  'likely': 477,
#  'almost': 478,
#  'energy': 479,
#  'interest': 480,
#  'analyst': 481,
#  'private': 482,
#  'happen': 483,
#  'talk': 484,
#  'gonna': 485,
#  'least': 486,
#  'history': 487,
#  'small': 488,
#  'bottom': 489,
#  'newyork': 490,
#  'rise': 491,
#  'following': 492,
#  'privacy': 493,
#  'rate': 494,
#  'bear': 495,
#  'central': 496,
#  'banking': 497,
#  'fast': 498,
#  'biggest': 499,
#  'hash': 500,
#  'bit': 501,
#  'chance': 502,
#  'lower': 503,
#  'bet': 504,
#  'friends': 505,
#  'stay': 506,
#  'means': 507,
#  '🙋': 508,
#  'sold': 509,
#  '🤔': 510,
#  'talking': 511,
#  'potential': 512,
#  'paid': 513,
#  'feel': 514,
#  'wealth': 515,
#  'retweet': 516,
#  'engineer': 517,
#  'development': 518,
#  'eur': 519,
#  '👇': 520,
#  'manager': 521,
#  'vet': 522,
#  'hot': 523,
#  'currencies': 524,
#  'within': 525,
#  '😎': 526,
#  'thought': 527,
#  'share': 528,
#  'important': 529,
#  'doge': 530,
#  '▶': 531,
#  'taking': 532,
#  '⬆': 533,
#  'amount': 534,
#  'opportunity': 535,
#  'reason': 536,
#  'services': 537,
#  'robotics': 538,
#  'control': 539,
#  'ask': 540,
#  'pretty': 541,
#  'create': 542,
#  'else': 543,
#  'retail': 544,
#  'gets': 545,
#  'cryptocurrencymarket': 546,
#  'e': 547,
#  'halving': 548,
#  '♂': 549,
#  'left': 550,
#  'place': 551,
#  'suggests': 552,
#  'technical': 553,
#  'coindesk': 554,
#  'able': 555,
#  'weeks': 556,
#  'robots': 557,
#  'hey': 558,
#  'others': 559,
#  'remember': 560,
#  'working': 561,
#  'fomo': 562,
#  'went': 563,
#  'social': 564,
#  'seen': 565,
#  'sing': 566,
#  'minutes': 567,
#  'entry': 568,
#  'wants': 569,
#  'guy': 570,
#  '❤': 571,
#  'firm': 572,
#  'artificailintelligence': 573,
#  'sec': 574,
#  'prediction': 575,
#  'question': 576,
#  'public': 577,
#  'behind': 578,
#  'article': 579,
#  'whole': 580,
#  'matic': 581,
#  'correction': 582,
#  'hits': 583,
#  'trending': 584,
#  'recent': 585,
#  'name': 586,
#  'bat': 587,
#  'continue': 588,
#  'total': 589,
#  'line': 590,
#  'rich': 591,
#  'amazing': 592,
#  'ath': 593,
#  'problem': 594,
#  'order': 595,
#  'found': 596,
#  '⟶': 597,
#  'agile': 598,
#  'btt': 599,
#  'called': 600,
#  'sportsbook': 601,
#  'card': 602,
#  'accept': 603,
#  'available': 604,
#  'july': 605,
#  'media': 606,
#  'instead': 607,
#  'due': 608,
#  'secure': 609,
#  'datascience': 610,
#  'agree': 611,
#  'btcnews': 612,
#  'june': 613,
#  'zec': 614,
#  'entrepreneur': 615,
#  'near': 616,
#  '👉': 617,
#  'ban': 618,
#  'paypal': 619,
#  'works': 620,
#  'massive': 621,
#  'research': 622,
#  'russia': 623,
#  'proof': 624,
#  'asia': 625,
#  'finally': 626,
#  'second': 627,
#  'iota': 628,
#  'marketing': 629,
#  'worst': 630,
#  'website': 631,
#  '•': 632,
#  'zero': 633,
#  'projects': 634,
#  'google': 635,
#  'interested': 636,
#  'volatility': 637,
#  'fact': 638,
#  'p': 639,
#  'either': 640,
#  'dip': 641,
#  'economy': 642,
#  'position': 643,
#  'net': 644,
#  'changes': 645,
#  'cybersecurity': 646,
#  'chinese': 647,
#  'craig': 648,
#  '💪': 649,
#  'care': 650,
#  'starting': 651,
#  'non': 652,
#  'artificialintelligence': 653,
#  'miss': 654,
#  'oh': 655,
#  'plan': 656,
#  'nano': 657,
#  'industry': 658,
#  'turn': 659,
#  'growth': 660,
#  'thinking': 661,
#  'average': 662,
#  'campaign': 663,
#  'expect': 664,
#  'bakkt': 665,
#  'created': 666,
#  'matter': 667,
#  'dgb': 668,
#  '⬇': 669,
#  'paper': 670,
#  'peter': 671,
#  'simple': 672,
#  'range': 673,
#  'cardano': 674,
#  'bounty': 675,
#  'crypto\r': 676,
#  'france': 677,
#  'cryptos': 678,
#  'icotracker': 679,
#  'levels': 680,
#  'singapore': 681,
#  'cost': 682,
#  'fun': 683,
#  'shows': 684,
#  'person': 685,
#  'fall': 686,
#  'fx': 687,
#  'crash': 688,
#  'fake': 689,
#  'imagine': 690,
#  'stockmarket': 691,
#  'fuck': 692,
#  'reuters': 693,
#  'lose': 694,
#  'startups': 695,
#  'korea': 696,
#  'green': 697,
#  'takes': 698,
#  'comes': 699,
#  'argentina': 700,
#  'state': 701,
#  'web': 702,
#  'list': 703,
#  'binary': 704,
#  'cointelegraph': 705,
#  'site': 706,
#  'bounce': 707,
#  'capital': 708,
#  'guess': 709,
#  'reach': 710,
#  'germany': 711,
#  'icos': 712,
#  'mind': 713,
#  'yeah': 714,
#  'vc': 715,
#  'president': 716,
#  'demand': 717,
#  'altseason': 718,
#  '🤑': 719,
#  'equity': 720,
#  'fed': 721,
#  'add': 722,
#  'action': 723,
#  'later': 724,
#  'source': 725,
#  'continues': 726,
#  'large': 727,
#  'watching': 728,
#  'inc': 729,
#  'pair': 730,
#  'yesterday': 731,
#  'aijobs': 732,
#  'launches': 733,
#  'dubai': 734,
#  '💥': 735,
#  'paying': 736,
#  'lt': 737,
#  'bears': 738,
#  'de': 739,
#  'bitmain': 740,
#  'double': 741,
#  'credit': 742,
#  'icx': 743,
#  'lead': 744,
#  'deposit': 745,
#  'sv': 746,
#  'trades': 747,
#  'chicago': 748,
#  '🏻': 749,
#  'running': 750,
#  'complete': 751,
#  'information': 752,
#  'course': 753,
#  'f': 754,
#  'freedom': 755,
#  'atm': 756,
#  'computer': 757,
#  'charts': 758,
#  'claim': 759,
#  'breakout': 760,
#  'access': 761,
#  '🙏': 762,
#  'york': 763,
#  'options': 764,
#  'min': 765,
#  'season': 766,
#  'miami': 767,
#  'miner': 768,
#  'core': 769,
#  'brazil': 770,
#  'build': 771,
#  'avg': 772,
#  'stable': 773,
#  'click': 774,
#  'changed': 775,
#  'silver': 776,
#  'size': 777,
#  'wallets': 778,
#  'enj': 779,
#  'venture': 780,
#  'im': 781,
#  'database': 782,
#  'spend': 783,
#  'protocol': 784,
#  'ny': 785,
#  'grow': 786,
#  'backed': 787,
#  'version': 788,
#  'deals': 789,
#  'home': 790,
#  'cannot': 791,
#  'test': 792,
#  'fee': 793,
#  'added': 794,
#  'leverage': 795,
#  'breaking': 796,
#  'xvg': 797,
#  'g': 798,
#  'breaks': 799,
#  'rvn': 800,
#  'panic': 801,
#  'southafrica': 802,
#  'nex': 803,
#  'shitcoin': 804,
#  'apple': 805,
#  'gain': 806,
#  'however': 807,
#  'phoenix': 808,
#  'save': 809,
#  'digitalcurrency': 810,
#  'solution': 811,
#  'loss': 812,
#  '🔻': 813,
#  '🚨': 814,
#  'bring': 815,
#  'moment': 816,
#  'offer': 817,
#  'job': 818,
#  'mexico': 819,
#  'took': 820,
#  'giving': 821,
#  'companies': 822,
#  'weekend': 823,
#  'crowdfunding': 824,
#  'single': 825,
#  'clear': 826,
#  'spain': 827,
#  'etf': 828,
#  'war': 829,
#  'head': 830,
#  'late': 831,
#  'growing': 832,
#  'largest': 833,
#  'transfer': 834,
#  'imo': 835,
#  'vaultmex': 836,
#  'peer': 837,
#  'crazy': 838,
#  'moves': 839,
#  'happens': 840,
#  'quantum': 841,
#  'italy': 842,
#  'ok': 843,
#  'technews': 844,
#  'drops': 845,
#  'ahead': 846,
#  'entrepreneurs': 847,
#  'white': 848,
#  'knows': 849,
#  'economic': 850,
#  'com': 851,
#  'red': 852,
#  'exactly': 853,
#  'opinion': 854,
#  'rsi': 855,
#  '😉': 856,
#  'bitcoinuk': 857,
#  'cricket': 858,
#  'forget': 859,
#  'washington': 860,
#  'wow': 861,
#  'omg': 862,
#  'founder': 863,
#  'portfolio': 864,
#  'cool': 865,
#  'cross': 866,
#  'half': 867,
#  'morning': 868,
#  'broke': 869,
#  'senior': 870,
#  'tax': 871,
#  'shitcoins': 872,
#  'story': 873,
#  'friend': 874,
#  'uae': 875,
#  'highs': 876,
#  'answer': 877,
#  'millions': 878,
#  'houston': 879,
#  'built': 880,
#  'towards': 881,
#  '👀': 882,
#  'according': 883,
#  'hedge': 884,
#  'universe': 885,
#  'view': 886,
#  'cuba': 887,
#  'entrepreneurship': 888,
#  'receive': 889,
#  'attention': 890,
#  'amazon': 891,
#  'techcrunch': 892,
#  'btch': 893,
#  'cleveland': 894,
#  'segwit': 895,
#  'mark': 896,
#  'cause': 897,
#  'product': 898,
#  'seattle': 899,
#  'dead': 900,
#  'gives': 901,
#  'told': 902,
#  'paris': 903,
#  'kucoin': 904,
#  'dallas': 905,
#  'ur': 906,
#  'despite': 907,
#  'dapp': 908,
#  'three': 909,
#  'luck': 910,
#  'nakamoto': 911,
#  'boston': 912,
#  'co': 913,
#  'atom': 914,
#  'tx': 915,
#  'malaysia': 916,
#  'antminer': 917,
#  'ont': 918,
#  'download': 919,
#  'neutral': 920,
#  'rewards': 921,
#  'memphis': 922,
#  'tokyo': 923,
#  'pro': 924,
#  'tomorrow': 925,
#  'austin': 926,
#  'orlando': 927,
#  'tokensales': 928,
#  'deal': 929,
#  'netherlands': 930,
#  'reserve': 931,
#  'august': 932,
#  'n': 933,
#  'event': 934,
#  'register': 935,
#  'ecommerce': 936,
#  'zil': 937,
#  'issue': 938,
#  'atlanta': 939,
#  'king': 940,
#  'ledger': 941,
#  'baltimore': 942,
#  'book': 943,
#  'wave': 944,
#  'rest': 945,
#  'sanjose': 946,
#  'scale': 947,
#  'pm': 948,
#  'area': 949,
#  'ooobtc': 950,
#  '⚡': 951,
#  'wright': 952,
#  'philadelphia': 953,
#  'god': 954,
#  'heard': 955,
#  'quick': 956,
#  'country': 957,
#  'tampa': 958,
#  'java': 959,
#  'steem': 960,
#  'fork': 961,
#  'bitcoinprice': 962,
#  'casino': 963,
#  'successful': 964,
#  'bitcoinrussia': 965,
#  'virginiabeach': 966,
#  'contract': 967,
#  '€': 968,
#  'kind': 969,
#  'alibaba': 970,
#  'monetary': 971,
#  'madison': 972,
#  'sense': 973,
#  'cricketworldcup': 974,
#  'solutions': 975,
#  'reward': 976,
#  'columbus': 977,
#  'charlotte': 978,
#  'positive': 979,
#  'jackma': 980,
#  'city': 981,
#  'user': 982,
#  'washingtondc': 983,
#  'hr': 984,
#  'minneapolis': 985,
#  '😍': 986,
#  'smartcontracts': 987,
#  'wish': 988,
#  'xtz': 989,
#  'law': 990,
#  'softbank': 991,
#  'together': 992,
#  'moscow': 993,
#  'bitcoinaustralia': 994,
#  'party': 995,
#  'rather': 996,
#  'trillion': 997,
#  'sydney': 998,
#  'venturecapital': 999,
#  ...}

# %%
model.wv.most_similar("btc")
# Out:
# [('bitcoin', 0.9114128947257996),
#  ('btc\r', 0.8768987655639648),
#  ('xrp', 0.871158242225647),
#  ('crypto', 0.84275883436203),
#  ('ltc', 0.8397266864776611),
#  ('eth', 0.8348677754402161),
#  ('today', 0.8314163684844971),
#  ('think', 0.829985499382019),
#  ('still', 0.8124943971633911),
#  ('usd', 0.8081998825073242)]

# %%
#genera i vettori
tweet2vec = [model.infer_vector((df['clean'][i].split(' '))) 
            for i in range(0,len(df['clean']))]
tweet2vec[:2]
# Out:
# [array([ 0.08962892, -0.01478323,  0.05245907,  0.05461497, -0.0188525 ,
#         -0.04777892,  0.0092875 ,  0.01618084, -0.10712815, -0.09093402,
#          0.03352208, -0.07498326, -0.06781733,  0.00666242, -0.02457455,
#          0.03793296, -0.11685763, -0.05576555, -0.05398546,  0.03973123,
#          0.0720048 ,  0.008313  ,  0.05347347, -0.13134374, -0.00815444,
#          0.04633424, -0.04227548, -0.11533497,  0.00181395,  0.00830524,
#         -0.01065396,  0.04598576, -0.11587417, -0.07234548,  0.01375864,
#          0.04261308,  0.02706897, -0.05922289,  0.07462559, -0.0369884 ,
#         -0.03731005, -0.03903158, -0.04075321,  0.02992823,  0.02780966,
#         -0.04794156, -0.04341198, -0.0423797 , -0.01117093,  0.05919836,
#          0.13711953, -0.04248716,  0.05999739,  0.02866414,  0.07604454,
#          0.06306117,  0.04247242, -0.01627171, -0.00887814, -0.00320528,
#         -0.0187212 , -0.11424013,  0.05072112, -0.02217848], dtype=float32),
#  array([ 0.16117923,  0.06269649, -0.13682964,  0.02602815,  0.1937511 ,
#         -0.20032084,  0.13470991,  0.03135711, -0.01509932, -0.04525535,
#         -0.21223526,  0.0138641 , -0.23233531, -0.21076046,  0.25641558,
#          0.04741854,  0.03870005,  0.0784912 , -0.08654279,  0.2880971 ,
#         -0.30329594,  0.12691104, -0.25476816,  0.36512828, -0.2554753 ,
#          0.03104049,  0.10864002, -0.26595804, -0.15391737,  0.41778275,
#         -0.11415363, -0.25464115, -0.05823544, -0.19616182,  0.20705839,
#         -0.08924209, -0.22849964, -0.00418737,  0.07803866,  0.10933355,
#          0.32557434,  0.17674762, -0.11488705, -0.02684874,  0.02161083,
#          0.09477093,  0.03348679,  0.03891359,  0.2110304 , -0.00934702,
#          0.02769865,  0.09990643, -0.04230508, -0.15802343,  0.08647905,
#          0.01367937, -0.23184453,  0.04348062,  0.08333305, -0.06030659,
#          0.22204195, -0.16804706, -0.03436199,  0.20624946], dtype=float32)]

# %%
import numpy as np
#Crea una lista di liste
dtv= np.array(tweet2vec).tolist()
#inserisce la list tra le colonne del dataframe
df['tweet2vec'] = dtv
df.head(2)
# Out:
#    Unnamed: 0        date        user               timestamp  \
# 0           0  2019-05-10  IdeasPrime  2019-05-10 21:42:01+00
# 1           4  2019-05-10  harbington  2019-05-10 13:20:10+00
#
#                                                clean     pos    neg    neu  \
# 0     btc usd btcusd btc usd btc fibs long short wcx  0.0000  0.000  1.000
# 1  eth also possible ethereum pump time bitcoin d...  0.5859  0.081  0.704
#
#    compound     value  week\r  \
# 0     0.000  bull\r\r      19
# 1     0.215  bull\r\r      19
#
#                                            tweet2vec
# 0  [0.12421877682209015, -0.01608162932097912, 0....
# 1  [-0.08004117757081985, -0.06177661940455437, -...

# %%
#trova i documenti più simili
model.dv.most_similar(1)
# Out:
# [(563075, 0.6433509588241577),
#  (573362, 0.6373852491378784),
#  (426576, 0.636681318283081),
#  (13223, 0.6200230717658997),
#  (570068, 0.6102948784828186),
#  (179431, 0.6058738827705383),
#  (222672, 0.605529248714447),
#  (34164, 0.6035187244415283),
#  (194992, 0.5991600155830383),
#  (171509, 0.595057487487793)]

# %%
test = "ath coming".split()
print(model.dv.most_similar([model.infer_vector(test)]))
# Out:
# [(91267, 0.7745657563209534), (472710, 0.7718918323516846), (54320, 0.7630526423454285), (476990, 0.7587276101112366), (72216, 0.7586725354194641), (26872, 0.7573115825653076), (420509, 0.7537076473236084), (99013, 0.7533555626869202), (539318, 0.7508599758148193), (381479, 0.7502236366271973)]

# %%
print(df.loc[91267])
# Out:
# Unnamed: 0                                                12939
# date                                                 2019-06-25
# user                                                     CamBTC
# timestamp                                2019-06-25 23:57:33+00
# clean                         expecting btc go ath alts recover
# pos                                                           0
# neg                                                           0
# neu                                                           1
# compound                                                      0
# value                                                  bull\r\r
# week\r                                                       26
# tweet2vec     [0.04444393143057823, 0.011828224174678326, 0....
# Name: 91267, dtype: object

# %%
print(df.loc[72216])
# Out:
# Unnamed: 0                                                45842
# date                                                 2019-06-08
# user                                                 SARL_SAGER
# timestamp                                2019-06-08 03:35:11+00
# clean                                       bitcoin moon boys\r
# pos                                                           0
# neg                                                           0
# neu                                                           1
# compound                                                      0
# value                                                  bull\r\r
# week\r                                                       23
# tweet2vec     [0.020176200196146965, -0.019622448831796646, ...
# Name: 72216, dtype: object

# %%
print(df.loc[472710])
# Out:
# Unnamed: 0                                                28994
# date                                                 2019-06-26
# user                                                RipzHustles
# timestamp                                2019-06-26 20:24:53+00
# clean                                      bitcoin ath soooooon
# pos                                                           0
# neg                                                           0
# neu                                                           1
# compound                                                      0
# value                                                  bull\r\r
# week\r                                                       26
# tweet2vec     [0.08409928530454636, 0.017843421548604965, 0....
# Name: 472710, dtype: object

# %%
test = "bitcoin value going up".split()
print(model.dv.most_similar([model.infer_vector(test)]))
# Out:
# [(449141, 0.7363398671150208), (10874, 0.7312799096107483), (21303, 0.695338785648346), (576569, 0.6950658559799194), (532008, 0.6943750381469727), (459119, 0.693573534488678), (473521, 0.6920057535171509), (267829, 0.6856286525726318), (419211, 0.6828756928443909), (40677, 0.6744663119316101)]

# %%
print(df.loc[449141])
# Out:
# Unnamed: 0                                                12492
# date                                                 2019-06-04
# user                                              theGoddessDri
# timestamp                                2019-06-04 16:43:49+00
# clean                       btc value going knew would happen\r
# pos                                                       0.324
# neg                                                           0
# neu                                                       0.676
# compound                                                   0.34
# value                                                  bear\r\r
# week\r                                                       23
# tweet2vec     [0.10508862882852554, 0.01932787522673607, 0.0...
# Name: 449141, dtype: object

# %%
#Verifica del tweet prima della pulizia del testo
df1 = pd.read_csv('.../drop2-4.csv', delimiter=',', skiprows=0, lineterminator='\n', low_memory=False)
df1
# Out:
#          Unnamed: 0        date             user               timestamp  \
# 0           2000001  2019-05-13      GigaBitcoin  2019-05-13 18:05:18+00
# 1           2000002  2019-05-13        cocainum_  2019-05-13 18:05:18+00
# 2           2000003  2019-05-13         ojo_azul  2019-05-13 18:05:18+00
# 3           2000004  2019-05-13         ojo_azul  2019-05-13 18:05:14+00
# 4           2000005  2019-05-13        Excellion  2019-05-13 18:05:15+00
# ...             ...         ...              ...                     ...
# 1999994     3999995  2019-06-18       joshgnosis  2019-06-18 11:08:20+00
# 1999995     3999996  2019-06-18  Vimalth82226643  2019-06-18 11:08:19+00
# 1999996     3999997  2019-06-18       FixedFloat  2019-06-18 11:08:17+00
# 1999997     3999998  2019-06-18     gaborgurbacs  2019-06-18 11:07:53+00
# 1999998     3999999  2019-06-18        247BitsHQ  2019-06-18 11:08:07+00
#
#                                                       text  compound    neg  \
# 0        Bitcoin at the Races: Overall Market Cap of #1...    0.0000  0.000
# 1        @BitBase_es A few days ago I saw a  dude tradi...   -0.4871  0.083
# 2        Arbistar 2.0, the Spanish version of bitcoin a...    0.0000  0.000
# 3        Arbistar 2.0, the Spanish version of bitcoin a...    0.0000  0.000
# 4        @hivedotone @WhalePanda @TraceMayer @bendavenp...    0.4215  0.000
# ...                                                    ...       ...    ...
# 1999994  @swearyanthony @crankynick I just remember it ...    0.0000  0.000
# 1999995  @cryptoastblog These Three Reasons Are Pushing...    0.3182  0.000
# 1999996  Exchange rates for today💚\n\n#BTC #ETH https:/...    0.0000  0.000
# 1999997  @TheStalwart Yes. The Libra-killer was unveile...    0.4019  0.000
# 1999998  Crypto Exchanges Are NOT Your Banks. A Cold St...    0.0000  0.000
#
#            neu  pos\r
# 0        1.000  0.000
# 1        0.917  0.000
# 2        1.000  0.000
# 3        1.000  0.000
# 4        0.781  0.219
# ...        ...    ...
# 1999994  1.000  0.000
# 1999995  0.929  0.071
# 1999996  1.000  0.000
# 1999997  0.803  0.197
# 1999998  1.000  0.000
#
# [1999999 rows x 9 columns]

# %%
pd.set_option('display.max_colwidth',700)

# %%
df1[df1.user== 'theGoddessDri']
# Out:
#          Unnamed: 0        date           user               timestamp  \
# 1338444     3338445  2019-06-04  theGoddessDri  2019-06-04 16:43:49+00
#
#                                                              text  compound  \
# 1338444  Btc value is going up again, I knew that would happen.\r      0.34
#
#          neg    neu  pos\r
# 1338444  0.0  0.789  0.211
